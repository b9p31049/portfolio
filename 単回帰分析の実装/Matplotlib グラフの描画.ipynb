# %%
import pandas as pd

# %%
df = pd.read_csv('sample.csv')

# %%
x = df['x']
y = df['y']

# %% [markdown]
# ## Matplotlib : グラフの描画

# %%
import matplotlib.pyplot as plt

# %%
# 横軸をx, 縦軸をyの散布図(scatter)をプロット
plt.scatter(x, y)
plt.show()
